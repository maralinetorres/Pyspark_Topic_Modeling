# %% [markdown]
# # Final Project - Running the Python scripts

# %%
# !python3 LDA_scratch.py "EuroParl-motions.pkl" "From-Scratch/Topics" "From-Scratch/Topic Score"
# Out:
# 21/10/18 23:20:51 WARN Utils: Your hostname, Maralines-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.99.161 instead (on interface en0)
# 21/10/18 23:20:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 21/10/18 23:20:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 21/10/18 23:20:53 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 21/10/18 23:20:53 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 21/10/18 23:20:53 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# ...

# %%
# !python3 LDA_MLLib.py "EuroParl-motions.pkl" "MLLib/Topics" "MLLib/Topic Score"
# Out:
# 21/10/18 23:40:28 WARN Utils: Your hostname, Maralines-MacBook-Pro.local resolves to a loopback address: 127.0.0.1; using 192.168.99.161 instead (on interface en0)
# 21/10/18 23:40:28 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 21/10/18 23:40:28 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 21/10/18 23:40:30 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 21/10/18 23:40:30 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 21/10/18 23:40:30 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# ...
